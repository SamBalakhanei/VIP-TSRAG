# %%
#%run, !python
# %run run_pipeline_baseline.py --device cpu --seq_len 256 --prediction_length 32 --epochs 1 --batch_size 32
# Out:
# [baseline] Pretraining baseline on fixed 10-stock subset
# c:\Users\rajcm\anaconda3\envs\tsrag\python.exe financial_pretrain.py --stocks_dir ../../sampled_stocks/new_directory --tickers OTEX PATH PUBM GOOGL ADP CBRE BLK FRT PINS MKTX --pretrained_model_path amazon/chronos-bolt-base --save_dir ./checkpoints/financial_finetuned_fixed10 --seq_len 256 --pred_len 32 --batch_size 32 --epochs 1
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File C:\VIP\VIP-TSRAG\TS-RAG-main\TS-RAG\run_pipeline_baseline.py:89
#      85     print("\n[baseline] Pipeline completed successfully.")
#      88 if __name__ == "__main__":
# ---> 89     main()
#
# File C:\VIP\VIP-TSRAG\TS-RAG-main\TS-RAG\run_pipeline_baseline.py:66, in main()
#      44 args = parser.parse_args()
#      46 pretrain_cmd = [
#      47     sys.executable,
#      48     "financial_pretrain.py",
#    (...)
# ...

# %%
# %run run_pipeline_tsrag_light.py --device cpu --context_length 256 --prediction_length 32 --batch_size 64 --train_steps 1200 --evaluation_steps 300 --top_k 5

# %%
# %run run_pipeline_tsrag_full.py --device cpu --artifact_device cpu --context_length 256 --prediction_length 32 --batch_size 64 --train_steps 800 --evaluation_steps 200 --top_k 5
# Out:
# [tsrag-full] Building aggregated stocks.csv
# c:\Users\rajcm\anaconda3\envs\tsrag\python.exe build_stocks_csv.py
#
# [tsrag-full] Building full TS-RAG retrieval/pretrain artifacts (fixed 10-stock subset)
# c:\Users\rajcm\anaconda3\envs\tsrag\python.exe build_stocks_retrieval_pretrain_full.py --device cpu

# %%
# %run run_pipeline_tsrag_full_sector.py --device cpu --artifact_device cpu --context_length 256 --prediction_length 32 --batch_size 64 --train_steps 800 --evaluation_steps 200 --top_k 5 --candidate_multiplier 2 --sector_bonus 0.10 --naics_bonus 0.15
